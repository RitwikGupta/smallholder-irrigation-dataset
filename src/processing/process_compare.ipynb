# %%
# from geometries import survey_polygon
from survey_to_csv import process_xml_zip
from polygons_to_geojson import kml_to_geojson

# %%
xml_zip = "../../data/labels/labeled_surveys/random_sample/DSB_1-25.zip"
df = process_xml_zip(xml_zip, original_location_file="../../data/sampling/samples/random_sample/Zambia_0.05_n_1-25.csv")

xml_zip = "../../data/labels/labeled_surveys/random_sample/DSB_101-125.zip"
df = process_xml_zip(xml_zip, original_location_file="../../data/sampling/samples/random_sample/Zambia_0.05_n_101-125.csv")

xml_zip = "../../data/labels/labeled_surveys/random_sample/KL_51-75.zip"
df = process_xml_zip(xml_zip, original_location_file="../../data/sampling/samples/random_sample/Zambia_0.05_n_51-75.csv")

xml_zip = "../../data/labels/labeled_surveys/random_sample/KL_101-125.zip"
df = process_xml_zip(xml_zip, original_location_file="../../data/sampling/samples/random_sample/Zambia_0.05_n_101-125.csv")
# Out:
# CSV successfully created at: ../../data/labels/labeled_surveys/random_sample/DSB_1-25.csv
#       site_id  internal_id               plot_file operator operator_initials  \
# 0  id_5213073            4  Zambia_0.05_n_1-25.csv     None               DSB
# 1  id_5201322            5  Zambia_0.05_n_1-25.csv     None               DSB
# 2  id_5038665           24  Zambia_0.05_n_1-25.csv     None               DSB
# 3  id_5145908           10  Zambia_0.05_n_1-25.csv     None               DSB
# 4  id_5145908           10  Zambia_0.05_n_1-25.csv     None               DSB
#
#                     x                    y water_source  image_number  year  \
# 0  26.872521622247284  -16.550263111712955         true             1  2018
# 1  26.302066039459145  -16.196592600070733        false             1  2023
# 2   29.34947859029196  -10.203145050736977         true             1  2017
# 3   28.28370900561473  -14.395097143646572        false             1  2024
# ...

# %%
kml = "../../data/labels/labeled_surveys/random_sample/DSB_1-25.kml"
df = kml_to_geojson(kml)

kml = "../../data/labels/labeled_surveys/random_sample/DSB_101-125.kml"
df = kml_to_geojson(kml)

kml = "../../data/labels/labeled_surveys/random_sample/KL_51-75.kml"
df = kml_to_geojson(kml)

kml = "../../data/labels/labeled_surveys/random_sample/KL_101-125.kml"
df = kml_to_geojson(kml)
# Out:
# GeoJSON written to ../../data/labels/labeled_surveys/random_sample/DSB_1-25.geojson
#                                             geometry              name  \
# 0  POLYGON ((31.27247 -11.08762, 31.27261 -11.088...  DSB_21_6.12.2024
# 1  POLYGON ((31.27437 -11.08887, 31.27449 -11.089...  DSB_21_6.12.2024
# 2  POLYGON ((31.27476 -11.08859, 31.27502 -11.089...  DSB_21_6.12.2024
# 3  POLYGON ((31.27608 -11.09014, 31.27609 -11.090...  DSB_21_6.12.2024
# 4  POLYGON ((31.27694 -11.09248, 31.27679 -11.092...  DSB_21_6.12.2024
#
#   operator_initials  internal_id  month  day  year  certainty  \
# 0               DSB           21      6   12  2024          3
# 1               DSB           21      6   12  2024          3
# 2               DSB           21      6   12  2024          3
# 3               DSB           21      6   12  2024          3
# 4               DSB           21      6   12  2024          3
#
#   uncertainty_explanation  plantation  commercial color  color_im_num
# ...

# %%
    survey = "../../data/labels/labeled_surveys/random_sample/DSB_1-25.csv"
    survey_results = merge_and_check(survey)
    print(survey_results.head())

    survey = "../../ddata/labels/labeled_surveys/random_sample/DSB_101-125.csv"
    survey_results = merge_and_check(survey)
    print(survey_results.head())

    survey = "../../ddata/labels/labeled_surveys/random_sample/KL_101-125.csv"
    survey_results = merge_and_check(survey)
    print(survey_results.head())

    survey = "../../ddata/labels/labeled_surveys/random_sample/KL_51-75.csv"
    survey_results = merge_and_check(survey)
    print(survey_results.head())
